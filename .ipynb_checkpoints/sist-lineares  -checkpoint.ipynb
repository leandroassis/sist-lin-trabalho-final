# %% [markdown]
# # Trabalho de Sistemas Lineares I
#
# ## Grupo 2 - Diogo Lima, Karinna Caiaffa, Leandro Assis e Raiane Marinho

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Importação de bibliotecas para desenvolvimento dos cálculos (sympy e numpy) e plotagem dos gráficos (matplotlib)

# %%
sp.init_printing()
plt.rcParams['figure.figsize'] = 10,10
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = False

t = sp.symbols('t', real=True)
s = sp.symbols('s', real=False)
j = sp.I*1
omega, beta = sp.symbols('omega, beta', real=True)
degrau = sp.Heaviside(t)

# Configuração da saída visual e criação das variáveis empregadas ao longo do trabalho

# %%
def LaPlace(funcao): # Função de cálculo da transformada de laPlace
    return sp.laplace_transform(funcao, t, s, noconds=True)

def InversaLaPlace(Funcao): #Função de cálculo da inversa de LaPlace
    return sp.inverse_laplace_transform(Funcao, s, t, noconds=True)

def Fourier(funcao): # Função de cálculo da transformada de LaPlace
    s = I*omega
    return sp.laplace_transform(funcao, t, s, noconds=True)

def H_s(beta): # Função de transferência do sistema estudado neste trabalho
    return (48+2*beta**2)/(s**2+2*beta*s+(24+beta)**2)

def symplot(F, intervalo, funLabel, xLabel, yLabel, legend=True): # Função para plotar gráficos
    f_num = np.zeros(intervalo.shape)
    for indT in range(0, intervalo.size):
        f_num[indT] = F.evalf(subs={t:intervalo[indT]})

    plt.plot(intervalo, f_num, label=funLabel)
    if legend == True:
        plt.legend();
    plt.xlim([min(intervalo), max(intervalo)]);
    plt.xlabel(xLabel);
    
def polos(func, simbolo=s):
    return solve(func, simbolo)

def analise_linear(b0, a1, a0): # Recebe os valores de b0, a1 e a0 e retorna os valores de wn, α e K
    wn = sp.sqrt(a0)
    alpha = a1/(2*wn)
    K = b0/a0
    return wn, alpha, K

def Modulo(numerador, denominador):
    return 20*sp.log(sp.sqrt(sp.re(numerador)**2+ sp.im(numerador)**2)) - 20*sp.log(sp.sqrt(sp.re(denominador)**2+ sp.im(denominador)**2))
    
def Fase(numerador, denominador):
    return sp.atan(sp.im(numerador)/sp.re(numerador)) - sp.atan(sp.im(denominador)/sp.re(denominador))

def DiagramaDeBode(funcaoModulo, funcaoFase, intervalo, titulo):
    fig, (Gmodulo, Gfase) = plt.subplots(2)
    fig.suptitle(titulo)
    
    for loop in range(2):
        if loop == 0: # Iteração para esboçar gráfico de módulo
            f_num = np.zeros(intervalo.shape)
            for indW in range(0, intervalo.size):
                f_num[indW] = funcaoModulo.evalf(subs={omega:intervalo[indW]})
            Gmodulo.plot(intervalo, f_num, 'tab:red')
            Gmodulo.set_title('Diagrama de módulo')
            Gmodulo.set(xlabel='Frequência (ω)', ylabel='Módulo, dB')
        else:
            for indW in range(0, intervalo.size):
                f_num[indW] = funcaoFase.evalf(subs={omega:intervalo[indW]})
            Gfase.plot(intervalo, f_num, 'tab:blue')
            Gfase.set_title('Diagrama de fase')
            Gfase.set(xlabel='Frequência (ω)', ylabel='Graus, θ')
        
# Definição das funções úteis ao longo do trabalho

# %% [markdown]
# ### Questão 1)

# %%
for beta in range(0,100,5): 
    y_f = InversaLaPlace(H_s(beta)*LaPlace(degrau)) # Cálculo da resposta ao estado zero para diferentes valores de β
    intervalo = np.arange(-1, 2, 0.01) # Criação do intervalo de tempo para o qual as funções y_f(t) serão plotadas
    symplot(y_f, intervalo, 'β='+str(beta), 'tempo [s]', 'y_f(t)') # Plotagem das funções com diferentes β

# %% [markdown]
# Plotando as resposta ao estado zero para valores de β de 0 à 100 com intervalo de 5 unidades, obtém-se os gráficos acima. Como é possível notar, para valores de β maiores que zero tem-se um sistema subamortecido que tende à estabilidade conforme β cresce e/ou com o passar de um dado tempo.
#
# Como deve-se escolher apenas 3 valores de β que provoquem diferenças no gráfico produzido, escolhe-se, para seguir com o trabalho, os valores 0, 2 e 65. Fez-se essa escolha pois em β igual a 0 o gráfico y(t) se torna um sinal senoidal, em β igual a 2 tem-se início a apresentação de característica subamortecida na saída do sistema, e em β igual a 65 observa-se a característica subamortecida com tempo de decaimento curtíssimo.

# %%
for beta in [0,2,65]:
    y_f = InversaLaPlace(H_s(beta)*LaPlace(degrau))
    intervalo = np.arange(-1, 2, 0.01)
    symplot(y_f, intervalo, 'β='+str(beta), 'tempo [s]', 'y_f(t)')

# %%
H_s(0), H_s(2), H_s(65) # Apresentação dos operadores de transferência avaliados nos valores de β escolhidos
# Out:
# ⎛   48           56               8498      ⎞
# ⎜────────, ──────────────, ─────────────────⎟
# ⎜ 2         2               2               ⎟
# ⎝s  + 576  s  + 4⋅s + 676  s  + 130⋅s + 7921⎠

# %%
polos(s**2+576), polos(s**2+4*s+676), polos(s**2+130*s+7921)]
# Cálculo dos pólos de cada operador de transferência acima
# Out:
# ([-24⋅ⅈ, 24⋅ⅈ], [-2 - 4⋅√42⋅ⅈ, -2 + 4⋅√42⋅ⅈ], [-65 - 4⋅√231⋅ⅈ, -65 + 4⋅√231⋅ⅈ]
# )

# %%
analise_linear(48, 0, 576), analise_linear(56, 4, 676), analise_linear(8498, 130, 7921)
# Análise de w_n, α e K para cada operador
# Out:
# ⎛                                                               ⎛    65
# ⎜(24, 0, 0.08333333333333333), (26, 1/13, 0.08284023668639054), ⎜89, ──, 1.072
# ⎝                                                               ⎝    89
#
#              ⎞⎞
# 8443378361319⎟⎟
#              ⎠⎠

# %% [markdown]
# ### Questão 2)

# %%
# Printa as três expressões da resposta em frequência H(jω) para os valores de β
H_jw = []
for beta in [0,2,65]:
    s = j*omega # Define s = 0 + jω 
    H_jw.append(H_s(beta)) # Calcula o valor da resposta em frequência H(jω) para cada valor escolhido para β
H_jw
# Out:
# ⎡   48             56                   8498        ⎤
# ⎢────────, ──────────────────, ─────────────────────⎥
# ⎢       2     2                   2                 ⎥
# ⎣576 - ω   - ω  + 4⋅ⅈ⋅ω + 676  - ω  + 130⋅ⅈ⋅ω + 7921⎦

# %%
# Expressões de módulo e fase (respectivamente) da resposta em frequência H(jω) para β = 0
Modulo(48, 576-omega**2), Fase(48, 576-omega**2)
# Out:
# ⎛        ⎛│ 2      │⎞                ⎞
# ⎝- 20⋅log⎝│ω  - 576│⎠ + 20⋅log(48), 0⎠

# %%
# Expressões de módulo e fase (respectivamente) da resposta em frequência H(jω) para β = 2
Modulo(56, 676-omega**2+4*j*omega), Fase(56, 676-omega**2+4*j*omega)
# Out:
# ⎛        ⎛    _____________________⎞                              ⎞
# ⎜        ⎜   ╱                   2 ⎟                              ⎟
# ⎜        ⎜  ╱      2   ⎛       2⎞  ⎟                    ⎛  4⋅ω   ⎞⎟
# ⎜- 20⋅log⎝╲╱   16⋅ω  + ⎝676 - ω ⎠  ⎠ + 20⋅log(56), -atan⎜────────⎟⎟
# ⎜                                                       ⎜       2⎟⎟
# ⎝                                                       ⎝676 - ω ⎠⎠

# %%
# Expressões de módulo e fase (respectivamente) da resposta em frequência H(jω) para β = 65
Modulo(8498, 7921-omega**2+130*j*omega), Fase(8498, 7921-omega**2+130*j*omega)
# Out:
# ⎛        ⎛    _________________________⎞                                 ⎞
# ⎜        ⎜   ╱                       2 ⎟                                 ⎟
# ⎜        ⎜  ╱         2   ⎛        2⎞  ⎟                      ⎛  130⋅ω  ⎞⎟
# ⎜- 20⋅log⎝╲╱   16900⋅ω  + ⎝7921 - ω ⎠  ⎠ + 20⋅log(8498), -atan⎜─────────⎟⎟
# ⎜                                                             ⎜        2⎟⎟
# ⎝                                                             ⎝7921 - ω ⎠⎠

# %%
# Diagrama de Bode para β igual = 0
DiagramaDeBode(Modulo(48, 576-omega**2), Fase(48, 576-omega**2), np.arange(-25*sp.pi, 25*sp.pi, 0.01), 'Diagrama de Bode para β = 0')

# %%
# Diagrama de Bode para β igual a 2
DiagramaDeBode(Modulo(56, -omega**2+4*j*omega+676), Fase(56, -omega**2+4*j*omega+676), np.arange(-50*sp.pi, 50*sp.pi, 0.01),'Diagrama de Bode para β = 2')

# %%
# Diagrama de Bode para β igual a 65
DiagramaDeBode(Modulo(8498, 7921-omega**2+130*j*omega), Fase(8498, 7921-omega**2+130*j*omega), np.arange(-25*sp.pi, 25*sp.pi, 0.01), 'Diagrama de Bode para β = 65')

# %% [markdown]
# ### Questão 3)

# %%
intervalo = np.arange(-100, 100, 0.5)
for beta in [15, 45, 80]:
    s = j*omega
    DiagramaDeBode(Modulo(H_s(beta).as_numer_denom()[0], H_s(beta).as_numer_denom()[1]), Fase(H_s(beta).as_numer_denom()[0], H_s(beta).as_numer_denom()[1]), intervalo, 'Diagrama de Bode para 3 valores de beta')

# %%
funcao_senoidal = sp.sin(omega*t) # f_senoidal = sen(ωt)
beta = 80
intervalo = np.arange(0, 60, 0.5)
for omega in [5, 25, 57.5]:
    s = j*omega
    mod = Modulo(H_s(beta).as_numer_denom()[0], H_s(beta).as_numer_denom()[1])
    fase = Fase(H_s(beta).as_numer_denom()[0], H_s(beta).as_numer_denom()[1])
    y_rp = mod*sp.sin(omega*t + fase)
    symplot(y_rp, intervalo, 'ω='+str(omega), 'tempo (s)', 'y_rp')

# %% [markdown]
# ## Referência Bibliográfica:
#
# https://www.youtube.com/watch?v=gbbvMg7Ird0
